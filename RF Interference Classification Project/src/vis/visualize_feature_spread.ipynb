# %%
import numpy as np
import matplotlib.pyplot  as plt

# %%
train_filepath = "my_data/superfeatures1/train.csv"
test_filepath = "my_data/superfeatures1/test.csv"

train_data = np.loadtxt(train_filepath, delimiter=",", skiprows=1)
test_data  = np.loadtxt(test_filepath,  delimiter=",", skiprows=1)

train_y = train_data[:, -1].astype(int)
test_y = test_data[:, -1].astype(int)

train_X1 = train_data[:, :-1]
test_X1  = test_data[:, :-1]

# %%
# for a label. plot histograms every 64 features
def plot_features_hists(label, data_X, data_y):
    # X: (num_samples, num_features)
    # y: (num_samples,)
    num_samples, num_features = len(data_X), len(data_X[0])
    num_hist = round(num_features / 64)
    print("num_hist: ", num_hist)
    print("num_samples: ", num_samples)

    X = data_X[data_y == label]
    print("in theory there should be a smaller num samples: ", len(X), " ", len(X[0]))

    f0 = 0
    for n in range(num_hist):
        f0 = n*64
        subX = X[:, f0:f0+64]

        print(f"f: {f0}:{f0+64}")
        print(f"subX: {subX.shape}")
        
        hist_X = np.mean(subX, axis=1)
        plt.figure(figsize=(5, 3))
        plt.hist(
            hist_X,
            bins = 100,
        )
        plt.xlim(0, 1)
        plt.ylabel("Density")
        plt.title(f"Feature Sum Distribution — Labels {label}")
        plt.tight_layout()
        plt.show()

# %%
plot_features_hists(1, train_X1, train_y)
# Out:
# num_hist:  33
# num_samples:  12915
# intheory should be smaller num samples:  2247   2112
# f: 0:64
# subX: (2247, 64)
# f: 64:128
# subX: (2247, 64)
# f: 128:192
# subX: (2247, 64)
# f: 192:256
# subX: (2247, 64)
# f: 256:320
# subX: (2247, 64)
# f: 320:384
# subX: (2247, 64)
# f: 384:448
# subX: (2247, 64)
# f: 448:512
# subX: (2247, 64)
# f: 512:576
# subX: (2247, 64)
# f: 576:640
# subX: (2247, 64)
# f: 640:704
# subX: (2247, 64)
# f: 704:768
# subX: (2247, 64)
# f: 768:832
# subX: (2247, 64)
# f: 832:896
# subX: (2247, 64)
# f: 896:960
# subX: (2247, 64)
# f: 960:1024
# subX: (2247, 64)
# f: 1024:1088
# subX: (2247, 64)
# f: 1088:1152
# subX: (2247, 64)
# f: 1152:1216
# subX: (2247, 64)
# f: 1216:1280
# subX: (2247, 64)
# f: 1280:1344
# subX: (2247, 64)
# f: 1344:1408
# subX: (2247, 64)
# f: 1408:1472
# subX: (2247, 64)
# f: 1472:1536
# subX: (2247, 64)
# f: 1536:1600
# subX: (2247, 64)
# f: 1600:1664
# subX: (2247, 64)
# f: 1664:1728
# subX: (2247, 64)
# f: 1728:1792
# ...

# %%
plot_features_hists(8, train_X1, train_y)
# Out:
# num_hist:  33
# num_samples:  12915
# intheory should be smaller num samples:  126   2112
# f: 0:64
# subX: (126, 64)
# f: 64:128
# subX: (126, 64)
# f: 128:192
# subX: (126, 64)
# f: 192:256
# subX: (126, 64)
# f: 256:320
# subX: (126, 64)
# f: 320:384
# subX: (126, 64)
# f: 384:448
# subX: (126, 64)
# f: 448:512
# subX: (126, 64)
# f: 512:576
# subX: (126, 64)
# f: 576:640
# subX: (126, 64)
# f: 640:704
# subX: (126, 64)
# f: 704:768
# subX: (126, 64)
# f: 768:832
# subX: (126, 64)
# f: 832:896
# subX: (126, 64)
# f: 896:960
# subX: (126, 64)
# f: 960:1024
# subX: (126, 64)
# f: 1024:1088
# subX: (126, 64)
# f: 1088:1152
# subX: (126, 64)
# f: 1152:1216
# subX: (126, 64)
# f: 1216:1280
# subX: (126, 64)
# f: 1280:1344
# subX: (126, 64)
# f: 1344:1408
# subX: (126, 64)
# f: 1408:1472
# subX: (126, 64)
# f: 1472:1536
# subX: (126, 64)
# f: 1536:1600
# subX: (126, 64)
# f: 1600:1664
# subX: (126, 64)
# f: 1664:1728
# subX: (126, 64)
# f: 1728:1792
# subX: (126, 64)
# f: 1792:1856
# ...

# %%
plot_features_hists(2, train_X1, train_y)
# Out:
# num_hist:  33
# num_samples:  12915
# intheory should be smaller num samples:  5451   2112
# f: 0:64
# subX: (5451, 64)
# f: 64:128
# subX: (5451, 64)
# f: 128:192
# subX: (5451, 64)
# f: 192:256
# subX: (5451, 64)
# f: 256:320
# subX: (5451, 64)
# f: 320:384
# subX: (5451, 64)
# f: 384:448
# subX: (5451, 64)
# f: 448:512
# subX: (5451, 64)
# f: 512:576
# subX: (5451, 64)
# f: 576:640
# subX: (5451, 64)
# f: 640:704
# subX: (5451, 64)
# f: 704:768
# subX: (5451, 64)
# f: 768:832
# subX: (5451, 64)
# f: 832:896
# subX: (5451, 64)
# f: 896:960
# subX: (5451, 64)
# f: 960:1024
# subX: (5451, 64)
# f: 1024:1088
# subX: (5451, 64)
# f: 1088:1152
# subX: (5451, 64)
# f: 1152:1216
# subX: (5451, 64)
# f: 1216:1280
# subX: (5451, 64)
# f: 1280:1344
# subX: (5451, 64)
# f: 1344:1408
# subX: (5451, 64)
# f: 1408:1472
# subX: (5451, 64)
# f: 1472:1536
# subX: (5451, 64)
# f: 1536:1600
# subX: (5451, 64)
# f: 1600:1664
# subX: (5451, 64)
# f: 1664:1728
# subX: (5451, 64)
# f: 1728:1792
# ...
